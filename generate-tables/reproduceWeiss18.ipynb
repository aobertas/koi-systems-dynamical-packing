# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import random
from scipy.stats import pearsonr
# %matplotlib inline
plt.style.use('paper')

# %%
df = pd.read_csv('cks_physical_merged.csv', index_col=0)
df.head(30)
# Out:
#    id_starname    id_kic id_koicand  id_kepler_name    koi_disposition  \
# 0       K00001  11446443  K00001.01      Kepler-1 b          CONFIRMED
# 1       K00002  10666592  K00002.01      Kepler-2 b          CONFIRMED
# 2       K00003  10748390  K00003.01      Kepler-3 b          CONFIRMED
# 3       K00006   3248033  K00006.01             NaN     FALSE POSITIVE
# 4       K00007  11853905  K00007.01      Kepler-4 b          CONFIRMED
# 5       K00008   5903312  K00008.01             NaN     FALSE POSITIVE
# 6       K00010   6922244  K00010.01      Kepler-8 b          CONFIRMED
# 7       K00017  10874614  K00017.01      Kepler-6 b          CONFIRMED
# 8       K00018   8191672  K00018.01      Kepler-5 b          CONFIRMED
# 9       K00020  11804465  K00020.01     Kepler-12 b          CONFIRMED
# 10      K00022   9631995  K00022.01    Kepler-422 b          CONFIRMED
# 11      K00041   6521045  K00041.01    Kepler-100 c          CONFIRMED
# 12      K00041   6521045  K00041.02    Kepler-100 b          CONFIRMED
# 13      K00041   6521045  K00041.03    Kepler-100 d          CONFIRMED
# 14      K00042   8866102  K00042.01  Kepler-410 A b          CONFIRMED
# 15      K00046  10905239  K00046.01    Kepler-101 b          CONFIRMED
# 16      K00046  10905239  K00046.02    Kepler-101 c          CONFIRMED
# 17      K00049   9527334  K00049.01    Kepler-461 b          CONFIRMED
# 18      K00063  11554435  K00063.01     Kepler-63 b          CONFIRMED
# 19      K00064   7051180  K00064.01             NaN  NOT DISPOSITIONED
# 20      K00069   3544595  K00069.01     Kepler-93 b          CONFIRMED
# 21      K00070   6850504  K00070.01     Kepler-20 c          CONFIRMED
# 22      K00070   6850504  K00070.02     Kepler-20 b          CONFIRMED
# 23      K00070   6850504  K00070.03     Kepler-20 d          CONFIRMED
# 24      K00070   6850504  K00070.05     Kepler-20 f          CONFIRMED
# 25      K00070   6850504  K00070.04     Kepler-20 e          CONFIRMED
# 26      K00072  11904151  K00072.01     Kepler-10 b          CONFIRMED
# 27      K00072  11904151  K00072.02     Kepler-10 c          CONFIRMED
# 28      K00075   7199397  K00075.01             NaN          CANDIDATE
# 29      K00082  10187017  K00082.01    Kepler-102 e          CONFIRMED
#
#     koi_period  koi_period_err1  koi_period_err2    koi_time0  koi_time0_err1  \
# 0     2.470613     1.900000e-08    -1.900000e-08  2454955.763        0.000006
# 1     2.204735     3.800000e-08    -3.800000e-08  2454954.359        0.000014
# 2     4.887803     1.770000e-07    -1.770000e-07  2454957.813        0.000028
# 3     1.334104     7.070000e-07    -7.070000e-07  2454966.702        0.000420
# 4     3.213669     1.122000e-06    -1.122000e-06  2454956.612        0.000280
# 5     1.160153     4.270000e-07    -4.270000e-07  2454954.704        0.000369
# 6     3.522499     1.940000e-07    -1.940000e-07  2454954.119        0.000046
# 7     3.234699     1.130000e-07    -1.130000e-07  2454954.487        0.000028
# 8     3.548465     1.960000e-07    -1.960000e-07  2454955.901        0.000046
# 26      ...           -0.172980  0.016828      0.000280     -0.000280
# 27      ...           -0.269843  0.240635      0.004008     -0.004008
# 28      ...           -1.199390  0.461982      0.007939     -0.007939
# 29      ...           -0.245213  0.116279      0.001953     -0.001953
#
#       iso_insol  iso_insol_err1  iso_insol_err2      iso_teq  iso_teq_err1  \
# 0    890.712853      184.876216     -184.876216  1392.188224     71.758330
# 1   3029.593093      931.186264     -931.186264  1890.643307    146.140168
# 2    116.907786       20.094411      -20.094411   837.962116     35.981752
# 3   3595.445148      694.155894     -694.155894  1973.338972     95.179897
# 4   1233.844672      367.335736     -367.335736  1510.353647    112.889880
# 5   2211.175946      378.322751     -378.322751  1747.508720     74.047754
# 6   1008.984582      285.797628     -285.797628  1436.265269    101.510972
# 7    978.501477      284.166523     -284.166523  1425.292164    103.051539
# 8   1483.296079      478.292268     -478.292268  1581.504702    127.993235
# 9   1004.271661      302.385394     -302.385394  1434.585139    107.335685
# 10   316.017155       92.855658      -92.855658  1074.462322     78.839702
# 11   205.741751       61.011727      -61.011727   965.148487     71.352338
# 12   470.454733      139.442304     -139.442304  1186.842219     88.237666
# 13    53.079626       15.708409      -15.708409   687.852770     50.859311
# 14   120.122552       29.048632      -29.048632   843.664284     50.876229
# 15  1030.563356      279.370300     -279.370300  1443.883654     97.817569
# 16   497.053587      132.230587     -132.230587  1203.273436     79.680910
# 17   182.220882       39.637536      -39.637536   936.295772     50.592242
# 18   108.995003       18.260295      -18.260295   823.408171     34.486276
# 19  2952.130758      975.002733     -975.002733  1878.440415    154.739916
# 20   285.772451       49.153856      -49.153856  1047.776408     45.077567
# 21    84.441905       14.365129      -14.365129   772.508082     32.858922
# 22   355.352832       60.250547      -60.250547  1106.441537     46.692798
# 23     6.134883        1.052890       -1.052890   401.065313     17.139961
# 24    38.486330        6.440680       -6.440680   634.731645     26.433802
# 25   182.103797       31.010203      -31.010203   936.145332     39.695019
# 26  3509.973490      855.282979     -855.282979  1961.505295    119.566228
# 27    17.212188        4.145961       -4.145961   519.065958     31.223844
# 28    21.578859        6.257107       -6.257107   549.250730     39.915181
# 29    22.801676        3.931463       -3.931463   556.871789     23.926245
#
#     iso_teq_err2
# 0     -71.758330
# 1    -146.140168
# 2     -35.981752
# 3     -95.179897
# 4    -112.889880
# 5     -74.047754
# 6    -101.510972
# 7    -103.051539
# 8    -127.993235
# 9    -107.335685
# 10    -78.839702
# 11    -71.352338
# 12    -88.237666
# 13    -50.859311
# 14    -50.876229
# 15    -97.817569
# 16    -79.680910
# 17    -50.592242
# 18    -34.486276
# 19   -154.739916
# 20    -45.077567
# 21    -32.858922
# 22    -46.692798
# 23    -17.139961
# 24    -26.433802
# 25    -39.695019
# 26   -119.566228
# 27    -31.223844
# 28    -39.915181
# 29    -23.926245
#
# [30 rows x 120 columns]

# %%
multis = pd.DataFrame(columns = df.columns)
multis.head()
# Out:
# Empty DataFrame
# Columns: [id_starname, id_kic, id_koicand, id_kepler_name, koi_disposition, koi_period, koi_period_err1, koi_period_err2, koi_time0, koi_time0_err1, koi_time0_err2, koi_impact, koi_impact_err1, koi_impact_err2, koi_duration, koi_duration_err1, koi_duration_err2, koi_ingress, koi_ingress_err1, koi_ingress_err2, koi_depth, koi_depth_err1, koi_depth_err2, koi_ror, koi_ror_err1, koi_ror_err2, koi_srho, koi_srho_err1, koi_srho_err2, koi_prad, koi_prad_err1, koi_prad_err2, koi_sma, koi_sma_err1, koi_sma_err2, koi_teq, koi_teq_err1, koi_teq_err2, koi_insol, koi_insol_err1, koi_insol_err2, koi_dor, koi_dor_err1, koi_dor_err2, koi_max_mult_ev, koi_model_snr, koi_count, koi_num_transits, koi_steff, koi_steff_err1, koi_steff_err2, koi_slogg, koi_slogg_err1, koi_slogg_err2, koi_smet, koi_smet_err1, koi_smet_err2, koi_srad, koi_srad_err1, koi_srad_err2, koi_smass, koi_smass_err1, koi_smass_err2, koi_sage, koi_sage_err1, koi_sage_err2, koi_sparprov, kic_kepmag, kic_jmag, kic_hmag, kic_kmag, cks_fp, cks_steff, cks_steff_err1, cks_steff_err2, cks_slogg, cks_slogg_err1, cks_slogg_err2, cks_smet, cks_smet_err1, cks_smet_err2, cks_svsini, cks_svsini_err1, cks_svsini_err2, iso_steff, iso_steff_err1, iso_steff_err2, iso_slogg, iso_slogg_err1, iso_slogg_err2, iso_smet, iso_smet_err1, iso_smet_err2, iso_srad, iso_srad_err1, iso_srad_err2, iso_smass, iso_smass_err1, iso_smass_err2, iso_sage, ...]
# Index: []
#
# [0 rows x 120 columns]

# %%
for i, row in df.head().iterrows():
    multis = multis.append(row)

# %%
multis
# Out:
#   id_starname    id_kic id_koicand id_kepler_name koi_disposition  koi_period  \
# 0      K00001  11446443  K00001.01     Kepler-1 b       CONFIRMED    2.470613
# 1      K00002  10666592  K00002.01     Kepler-2 b       CONFIRMED    2.204735
# 2      K00003  10748390  K00003.01     Kepler-3 b       CONFIRMED    4.887803
# 3      K00006   3248033  K00006.01            NaN  FALSE POSITIVE    1.334104
# 4      K00007  11853905  K00007.01     Kepler-4 b       CONFIRMED    3.213669
#
#    koi_period_err1  koi_period_err2    koi_time0  koi_time0_err1  \
# 0     1.900000e-08    -1.900000e-08  2454955.763        0.000006
# 1     3.800000e-08    -3.800000e-08  2454954.359        0.000014
# 2     1.770000e-07    -1.770000e-07  2454957.813        0.000028
# 3     7.070000e-07    -7.070000e-07  2454966.702        0.000420
# 4     1.122000e-06    -1.122000e-06  2454956.612        0.000280
#
#        ...       iso_prad_err2   iso_sma  iso_sma_err1  iso_sma_err2  \
# 0      ...           -1.419266  0.035951      0.000596     -0.000596
# 1      ...           -2.018515  0.036880      0.000727     -0.000727
# 2      ...           -0.410257  0.052952      0.000883     -0.000883
# 3      ...          -21.966014  0.025383      0.000427     -0.000427
# 4      ...           -0.596032  0.044247      0.001075     -0.001075
#
#      iso_insol  iso_insol_err1  iso_insol_err2      iso_teq  iso_teq_err1  \
# 0   890.712853      184.876216     -184.876216  1392.188224     71.758330
# 1  3029.593093      931.186264     -931.186264  1890.643307    146.140168
# 2   116.907786       20.094411      -20.094411   837.962116     35.981752
# 3  3595.445148      694.155894     -694.155894  1973.338972     95.179897
# 4  1233.844672      367.335736     -367.335736  1510.353647    112.889880
#
#    iso_teq_err2
# 0    -71.758330
# 1   -146.140168
# 2    -35.981752
# 3    -95.179897
# 4   -112.889880
#
# [5 rows x 120 columns]

# %%
multis = pd.DataFrame(columns = df.columns)
for ID in df['id_starname'].unique():
    if (df['id_starname'] == ID).sum() > 1:
        for i, row in df[df['id_starname'] == ID].sort_values('koi_period').iterrows():
            multis=multis.append(row)

# %%
multis
# Out:
#      id_starname    id_kic id_koicand id_kepler_name    koi_disposition  \
# 12        K00041   6521045  K00041.02   Kepler-100 b          CONFIRMED
# 11        K00041   6521045  K00041.01   Kepler-100 c          CONFIRMED
# 13        K00041   6521045  K00041.03   Kepler-100 d          CONFIRMED
# 15        K00046  10905239  K00046.01   Kepler-101 b          CONFIRMED
# 16        K00046  10905239  K00046.02   Kepler-101 c          CONFIRMED
# 22        K00070   6850504  K00070.02    Kepler-20 b          CONFIRMED
# 25        K00070   6850504  K00070.04    Kepler-20 e          CONFIRMED
# 21        K00070   6850504  K00070.01    Kepler-20 c          CONFIRMED
# 24        K00070   6850504  K00070.05    Kepler-20 f          CONFIRMED
# 23        K00070   6850504  K00070.03    Kepler-20 d          CONFIRMED
# 26        K00072  11904151  K00072.01    Kepler-10 b          CONFIRMED
# 27        K00072  11904151  K00072.02    Kepler-10 c          CONFIRMED
# 33        K00082  10187017  K00082.05   Kepler-102 b          CONFIRMED
# 32        K00082  10187017  K00082.04   Kepler-102 c          CONFIRMED
# 30        K00082  10187017  K00082.02   Kepler-102 d          CONFIRMED
# 29        K00082  10187017  K00082.01   Kepler-102 e          CONFIRMED
# 31        K00082  10187017  K00082.03   Kepler-102 f          CONFIRMED
# 36        K00085   5866724  K00085.02    Kepler-65 b          CONFIRMED
# 35        K00085   5866724  K00085.01    Kepler-65 c          CONFIRMED
# 37        K00085   5866724  K00085.03    Kepler-65 d          CONFIRMED
# 40        K00094   6462863  K00094.04    Kepler-89 b          CONFIRMED
# 41        K00094   6462863  K00094.02    Kepler-89 c          CONFIRMED
# 43        K00094   6462863  K00094.01    Kepler-89 d          CONFIRMED
# 42        K00094   6462863  K00094.03    Kepler-89 e          CONFIRMED
# 46        K00099   8505215  K00099.02            NaN     FALSE POSITIVE
# 47        K00099   8505215  K00099.01            NaN  NOT DISPOSITIONED
# 48        K00102   8456679  K00102.01            NaN  NOT DISPOSITIONED
# 49        K00102   8456679  K00102.02            NaN  NOT DISPOSITIONED
# 55        K00108   4914423  K00108.01   Kepler-103 b          CONFIRMED
# 54        K00108   4914423  K00108.02   Kepler-103 c          CONFIRMED
# ...          ...       ...        ...            ...                ...
# 1829      K04212   1724719  K04212.02            NaN  NOT DISPOSITIONED
# 1837      K04246   5177859  K04246.01  Kepler-1576 b          CONFIRMED
# 1838      K04246   5177859  K04246.02            NaN          CANDIDATE
# 1842      K04269   8890924  K04269.02            NaN  NOT DISPOSITIONED
# 1841      K04269   8890924  K04269.01            NaN  NOT DISPOSITIONED
# 1846      K04287  11081504  K04287.02            NaN          CANDIDATE
# 1845      K04287  11081504  K04287.01            NaN          CANDIDATE
# 1847      K04288   4548011  K04288.01  Kepler-1581 b          CONFIRMED
# 1848      K04288   4548011  K04288.02            NaN  NOT DISPOSITIONED
# 1857      K04323   5385410  K04323.01            NaN          CANDIDATE
# 1858      K04323   5385410  K04323.02            NaN     FALSE POSITIVE
# 1865      K04368   5471489  K04368.01            NaN     FALSE POSITIVE
# 1866      K04368   5471489  K04368.02            NaN  NOT DISPOSITIONED
# 1868      K04382   6937529  K04382.01  Kepler-1597 b          CONFIRMED
# 1869      K04382   6937529  K04382.02            NaN  NOT DISPOSITIONED
# 1871      K04385   3645438  K04385.01            NaN          CANDIDATE
# 1873      K04385   3645438  K04385.03            NaN          CANDIDATE
# 1872      K04385   3645438  K04385.02  Kepler-1600 b          CONFIRMED
# 1884      K04431   9936080  K04431.01            NaN  NOT DISPOSITIONED
# 1885      K04431   9936080  K04431.02            NaN  NOT DISPOSITIONED
# 1886      K04435   8278685  K04435.01            NaN          CANDIDATE
# 1887      K04435   8278685  K04435.02            NaN          CANDIDATE
# 1903      K04567   8332521  K04567.02            NaN          CANDIDATE
# 1902      K04567   8332521  K04567.01            NaN          CANDIDATE
# 1920      K04647   9947653  K04647.02            NaN          CANDIDATE
# 1921      K04647   9947653  K04647.01            NaN          CANDIDATE
# 1924      K04657   6527078  K04657.01            NaN          CANDIDATE
# 1925      K04657   6527078  K04657.02            NaN          CANDIDATE
# 1951      K04829  12401132  K04829.02            NaN  NOT DISPOSITIONED
# 1950      K04829  12401132  K04829.01            NaN  NOT DISPOSITIONED
#
#        koi_period  koi_period_err1  koi_period_err2    koi_time0  \
# 12       6.887060     2.038000e-05    -2.038000e-05  2454966.178
# 11      12.815884     1.836000e-05    -1.836000e-05  2454955.948
# 13      35.333087     2.155000e-04    -2.155000e-04  2454986.983
# 15       3.487689     1.133000e-06    -1.133000e-06  2455003.932
# 16       6.029795     7.054000e-05    -7.054000e-05  2454965.482
# 22       3.696120     2.310000e-06    -2.310000e-06  2454967.502
# 25       6.098537     2.838000e-05    -2.838000e-05  2454968.930
# 21      10.854098     4.400000e-06    -4.400000e-06  2454971.608
# 24      19.577629     1.240000e-04    -1.240000e-04  2454968.206
# 23      77.611599     1.357000e-04    -1.357000e-04  2454997.727
# 26       0.837491     2.720000e-07    -2.720000e-07  2454964.575
# 27      45.294317     5.283000e-05    -5.283000e-05  2454971.677
# 33       5.286954     2.538000e-05    -2.538000e-05  2454968.852
# 32       7.071361     2.571000e-05    -2.571000e-05  2454972.987
# 30      10.311738     1.028000e-05    -1.028000e-05  2454967.081
# 29      16.145691     6.645000e-06    -6.645000e-06  2454967.754
# 31      27.453729     1.033000e-04    -1.033000e-04  2454978.023
# 36       2.154909     1.841000e-06    -1.841000e-06  2454966.499
# 35       5.859939     2.614000e-06    -2.614000e-06  2454965.040
# 37       8.131225     1.345000e-05    -1.345000e-05  2454970.992
# 40       3.743176     9.096000e-06    -9.096000e-06  2454964.619
# 41      10.423678     7.163000e-06    -7.163000e-06  2454971.009
# 1885     -0.017670     2.632859        0.675108       -0.675108   324.616374
# 1886     -0.002016   290.225396       88.506707      -88.506707  1051.834422
# 1887     -0.002779   149.259392       44.851703      -44.851703   890.735873
# 1903     -0.000970   791.931488      180.342681     -180.342681  1351.871551
# 1902     -0.002067   170.757295       39.214543      -39.214543   921.209361
# 1920     -0.002031   290.077858       87.175371      -87.175371  1051.700719
# 1921     -0.004329    62.144531       18.671787      -18.671787   715.507606
# 1924     -0.001206   105.933110       18.130888      -18.130888   817.563429
# 1925     -0.001478    68.862469       11.724656      -11.724656   734.106675
# 1951     -0.001847   173.875189       55.056265      -55.056265   925.386011
# 1950     -0.002849    74.198240       23.237622      -23.237622   747.931676
#
#       iso_teq_err1  iso_teq_err2
# 12       88.237666    -88.237666
# 11       71.352338    -71.352338
# 13       50.859311    -50.859311
# 15       97.817569    -97.817569
# 16       79.680910    -79.680910
# 22       46.692798    -46.692798
# 25       39.695019    -39.695019
# 21       32.858922    -32.858922
# 24       26.433802    -26.433802
# 23       17.139961    -17.139961
# 26      119.566228   -119.566228
# 27       31.223844    -31.223844
# 33       34.374405    -34.374405
# 32       31.111861    -31.111861
# 30       27.415631    -27.415631
# 29       23.926245    -23.926245
# 31       19.929448    -19.929448
# 36      127.461399   -127.461399
# 35       92.214607    -92.214607
# 37       80.689243    -80.689243
# 40       97.657722    -97.657722
# 41       69.607693    -69.607693
# 43       53.933309    -53.933309
# 42       39.250401    -39.250401
# 46             NaN           NaN
# 47        4.517902     -4.517902
# 48       93.389416    -93.389416
# 49       71.696916    -71.696916
# 55       64.308670    -64.308670
# 54       28.843235    -28.843235
# ...            ...           ...
# 1829     51.191294    -51.191294
# 1837     39.085365    -39.085365
# 1838     36.380476    -36.380476
# 1842    138.223874   -138.223874
# 1841     76.140394    -76.140394
# 1846     65.558130    -65.558130
# 1845     59.286865    -59.286865
# 1847     86.443876    -86.443876
# 1848     76.120958    -76.120958
# 1857     67.720094    -67.720094
# 1858     66.212648    -66.212648
# 1865     77.122274    -77.122274
# 1866     51.314599    -51.314599
# 1868     95.407842    -95.407842
# 1869     87.023291    -87.023291
# 1871     32.792275    -32.792275
# 1873     25.205396    -25.205396
# 1872      8.782599     -8.782599
# 1884     54.536564    -54.536564
# 1885     20.745988    -20.745988
# 1886     80.479220    -80.479220
# 1887     66.844436    -66.844436
# 1903     77.039330    -77.039330
# 1902     52.756061    -52.756061
# 1920     79.492600    -79.492600
# 1921     53.653047    -53.653047
# 1924     34.912771    -34.912771
# 1925     31.156165    -31.156165
# 1951     73.382237    -73.382237
# 1950     58.605040    -58.605040
#
# [1215 rows x 120 columns]

# %% [markdown]
# matches # in weiss 18 paper before her extra cuts

# %%
multis.shape
# Out:
# (1215, 120)

# %%
IDs = multis['id_starname'].unique()
ID = IDs[0]
ID
# Out:
# 'K00041'

# %%
s = multis[multis['id_starname'] == ID]
s
# Out:
#    id_starname   id_kic id_koicand id_kepler_name koi_disposition  koi_period  \
# 12      K00041  6521045  K00041.02   Kepler-100 b       CONFIRMED    6.887060
# 11      K00041  6521045  K00041.01   Kepler-100 c       CONFIRMED   12.815884
# 13      K00041  6521045  K00041.03   Kepler-100 d       CONFIRMED   35.333087
#
#     koi_period_err1  koi_period_err2    koi_time0  koi_time0_err1  \
# 12         0.000020        -0.000020  2454966.178         0.00239
# 11         0.000018        -0.000018  2454955.948         0.00110
# 13         0.000215        -0.000215  2454986.983         0.00481
#
#         ...       iso_prad_err2   iso_sma  iso_sma_err1  iso_sma_err2  \
# 12      ...           -0.235962  0.073338      0.001600     -0.001600
# 11      ...           -0.344682  0.110944      0.002407     -0.002407
# 13      ...           -0.318251  0.218115      0.004702     -0.004702
#
#      iso_insol  iso_insol_err1  iso_insol_err2      iso_teq  iso_teq_err1  \
# 12  470.454733      139.442304     -139.442304  1186.842219     88.237666
# 11  205.741751       61.011727      -61.011727   965.148487     71.352338
# 13   53.079626       15.708409      -15.708409   687.852770     50.859311
#
#     iso_teq_err2
# 12    -88.237666
# 11    -71.352338
# 13    -50.859311
#
# [3 rows x 120 columns]

# %%
for i in range(s.shape[0]-1):
    print(s.iloc[i]['koi_prad'], s.iloc[i+1]['koi_prad'])
# Out:
# 1.31 2.28
# 2.28 1.5

# %%
adj = pd.DataFrame(columns = ["R", "Rnext"])
for ID in multis['id_starname'].unique():
    s = multis[multis['id_starname'] == ID]
    for i in range(s.shape[0]-1):
        if ~np.isnan(s.iloc[i]['koi_prad']) and ~np.isnan(s.iloc[i+1]['koi_prad']): # both have measured radii
            if s.iloc[i]['koi_model_snr'] > 10 and s.iloc[i+1]['koi_model_snr'] > 10: # both high SNR
                if s.iloc[i]['koi_prad'] < 16 and s.iloc[i+1]['koi_prad'] < 16: # Smaller than 16  Earth radii
                    adj = adj.append(pd.Series({'R':s.iloc[i]['koi_prad'], 'Rnext':s.iloc[i+1]['koi_prad'], 'R_err1':s.iloc[i]['koi_prad_err1'], 'R_err2':s.iloc[i]['koi_prad_err2']}), ignore_index=True)

# %%
adj.shape[0]
# Out:
# 663

# %%
adj.head()
# Out:
#       R  Rnext  R_err1  R_err2
# 0  1.31   2.28    0.03   -0.03
# 1  2.28   1.50    0.06   -0.05
# 2  4.36   0.91    1.01   -0.55
# 3  2.11   0.82    0.37   -0.17
# 4  0.82   3.03    0.15   -0.06

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(adj['R'], adj['Rnext'], '.')
ax.set_xlim([0.25,16])
ax.set_ylim([0.25,16])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_aspect('equal')
ax.set_xlabel('R_i')
ax.set_ylabel('R_i+1')
ax.set_title('CKS')
ax.plot(np.linspace(0.25,16,10), np.linspace(0.25,16,10), '--')
ax.text(0.3, 6, 'Pearson R = {0:.2f}'.format(pearsonr(adj['R'], adj['Rnext'])[0]), fontsize=24)
# Out:
# Text(0.3,6,'Pearson R = 0.54')
# /Users/dtamayo/miniconda3/envs/p3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import sys
sys.path.append('../forecaster')
import mr_forecast as mr

# %%
Mspread = 0.5
M = mr.Rpost2M(adj['R'], unit='Earth', classify='Yes')
M = M[M < 100] # exclude jupiters+
Mnext = np.array([max(0.1*m, random.normal(m, Mspread*m, 1)[0]) for m in M])
# Out:
# Terran 23.7 %, Neptunian 75.7 %, Jovian 0.6 %, Star 0.0 %

# %%
fig, ax = plt.subplots()
ax.loglog(M, Mnext, '.')
# Out:
# /Users/dtamayo/miniconda3/envs/p3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
R = mr.Mpost2R(M, unit='Earth', classify='Yes')
Rnext = mr.Mpost2R(Mnext, unit='Earth', classify='Yes')
Robs, Rnextobs =  np.zeros(len(R)), np.zeros(len(R))
# Out:
# Terran 25.4 %, Neptunian 74.6 %, Jovian 0.0 %, Star 0.0 %
# Terran 32.1 %, Neptunian 67.9 %, Jovian 0.0 %, Star 0.0 %

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(R, Rnext, '.')
ax.set_xlim([0.25,16])
ax.set_ylim([0.25,16])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_aspect('equal')
ax.set_xlabel('R_i')
ax.set_ylabel('R_i+1')
ax.set_title('Equal Mass Planets w/ Forecaster Radii')
ax.plot(np.linspace(0.25,16,10), np.linspace(0.25,16,10), '--')
ax.text(0.3, 6, 'Pearson R = {0:.2f}'.format(pearsonr(R, Rnext)[0]), fontsize=24)
# Out:
# Text(0.3,6,'Pearson R = 0.65')
# /Users/dtamayo/miniconda3/envs/p3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(adj['R'], adj['Rnext'], '.')
ax.set_xlim([0.25,16])
ax.set_ylim([0.25,16])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_aspect('equal')
ax.set_xlabel('R_i')
ax.set_ylabel('R_i+1')
ax.set_title('CKS')
ax.plot(np.linspace(0.25,16,10), np.linspace(0.25,16,10), '--')
ax.text(0.3, 6, 'Pearson R = {0:.2f}'.format(pearsonr(adj['R'], adj['Rnext'])[0]), fontsize=24)
# Out:
# Text(0.3,6,'Pearson R = 0.54')
# /Users/dtamayo/miniconda3/envs/p3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
for i, r in enumerate(R):
    err = random.randint(2)
    # choose whether we measure above or below at random
    if err == 0:
        e = adj.iloc[i]['R_err1']
    else:
        e = adj.iloc[i]['R_err2']
    # err2 for below is < 0, so take a sample using abs(err), take the abs and use sign(err) for whether to add or sub
    Robs[i] = R[i] + np.sign(e)*np.abs(random.normal(0, np.abs(e), 1)[0])
    
    err = random.randint(2)
    # choose whether we measure above or below at random
    if err == 0:
        e = adj.iloc[i]['R_err1']
    else:
        e = adj.iloc[i]['R_err2']
    # err2 for below is < 0, so take a sample using abs(err), take the abs and use sign(err) for whether to add or sub
    Rnextobs[i] = Rnext[i] + np.sign(e)*np.abs(random.normal(0, np.abs(e), 1)[0])

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(Robs, Rnextobs, '.')
ax.set_xlim([0.25,16])
ax.set_ylim([0.25,16])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_aspect('equal')
ax.set_xlabel('R_i')
ax.set_ylabel('R_i+1')
ax.set_title('Equal Mass Forecaster Radii Obs Errors')
ax.plot(np.linspace(0.25,16,10), np.linspace(0.25,16,10), '--')
ax.text(0.3, 6, 'Pearson R = {0:.2f}'.format(pearsonr(R, Rnext)[0]), fontsize=24)
# Out:
# Text(0.3,6,'Pearson R = 0.72')
# /Users/dtamayo/miniconda3/envs/p3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(adj['R'], adj['Rnext'], '.')
ax.set_xlim([0.25,16])
ax.set_ylim([0.25,16])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_aspect('equal')
ax.set_xlabel('R_i')
ax.set_ylabel('R_i+1')
ax.set_title('CKS')
ax.plot(np.linspace(0.25,16,10), np.linspace(0.25,16,10), '--')
ax.text(0.3, 6, 'Pearson R = {0:.2f}'.format(pearsonr(adj['R'], adj['Rnext'])[0]), fontsize=24)
# Out:
# Text(0.3,6,'Pearson R = 0.54')
# /Users/dtamayo/miniconda3/envs/p3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
